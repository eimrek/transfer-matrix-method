# %%
import scipy as sp
import scipy.constants
import scipy.integrate
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
data = np.loadtxt("../data/potential_4.txt")

# %%
plt.plot(data[:, 0], data[:, 1], "-")
plt.axhline(0.0, linestyle="--", color="k")
#plt.axvline(1.64692)
#plt.xlim([0.99, 1.01])
#plt.ylim([0.0,1.0])
plt.show()

# %%
data = np.loadtxt("../data/tunnel_data_4.txt")
data2 = np.loadtxt("../data/tunnel_data_4_m-4.txt")

# %%
plt.plot(data[:, 0], data[:, 1], "-")
plt.plot(data2[:, 0], data2[:, 1], "r-")
#plt.axvline(1.64692)
#plt.xlim([6.0, 11.0])
#plt.ylim([1e-6,1.0])
plt.yscale('log')
plt.show()
